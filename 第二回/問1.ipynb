# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
def make_X(mu, sigme, size):
    X = np.random.multivariate_normal(mu, sigma, size)
    return X

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 1000

X = make_X(mu,sigma, size)

sns.jointplot(X[:,0], X[:,1])
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)

# %%
mu = np.array([100, -20])
sigma = np.array([[30, 20], [20, 50]])
size = 10000

X = make_X(mu,sigma, size)

sns.jointplot(X[:,0], X[:,1])
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 1000000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [-0.00176177 -0.00804747]
# sigma= [[30.0233301  20.01899154]
#  [20.01899154 49.9752736 ]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])

X_len = np.arange(10**2,10**5,10**3)

X = np.array([make_X(mu, sigma, size) for size in X_len])

# %%
mu_x = np.array([np.mean(X[i],axis=0) for i in range(len(X))])
sigma_x = np.array([np.cov(X[i].T) for i in range(len(X))])

plt.plot(X_len,  np.abs(mu - mu_x).mean(axis=1), c='r')
plt.plot(X_len, np.abs((sigma - sigma_x).mean(axis=1).mean(axis=1)))
plt.show()

# %%
mu = np.array([0, 0])
sigma = np.array([[3000, 20], [20, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1], xlim=(-200,200), ylim=(-200,200))
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [ 0.92937086 -0.10304019]
# sigma= [[3037.31178892   14.88693483]
#  [  14.88693483   50.50218127]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 5000]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1], xlim=(-200,200), ylim=(-200,200))
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [0.08802785 0.35057133]
# sigma= [[  30.08232817   15.70506224]
#  [  15.70506224 4961.78740613]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 30], [30, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [0.00566831 0.04073913]
# sigma= [[30.0689833  29.75561111]
#  [29.75561111 49.55411979]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 10], [10, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [0.10760575 0.02134399]
# sigma= [[29.83393905  9.69259567]
#  [ 9.69259567 50.05959705]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, -30], [-30, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [-0.00571486  0.03739567]
# sigma= [[ 29.96570326 -29.97453459]
#  [-29.97453459  49.96165578]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [ 0.01929973 -0.02030819]
# sigma= [[29.22507873 19.86521934]
#  [19.86521934 51.21325422]]

# %% [markdown]
# # 標準化

# %%
def zscore(x):
    xmean = x.mean(axis=0)
    xstd = np.std(x,axis=0)
    return (x - xmean) / xstd

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 10000

X = make_X(mu,sigma, size)

sns.jointplot(X[:,0], X[:,1], xlim=(-20,20), ylim=(-20,20))
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [-0.03381627 -0.01728325]
# sigma= [[30.13760452 19.8274277 ]
#  [19.8274277  50.6020965 ]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 10000

X = zscore(make_X(mu,sigma, size))

sns.jointplot(X[:,0], X[:,1], xlim=(-20,20), ylim=(-20,20))
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [9.76996262e-19 8.66418048e-17]
# sigma= [[1.00010001 0.51295086]
#  [0.51295086 1.00010001]]

# %% [markdown]
# # 無相関化

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 5], [5, 5]])
size = 10000

X = make_X(mu,sigma, size)

sns.jointplot(X[:,0], X[:,1], xlim=(-20,20), ylim=(-20,20))
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [0.02589851 0.03959202]
# sigma= [[30.06322774  5.03807551]
#  [ 5.03807551  5.03154954]]

# %%
ramda, S = np.linalg.eig(sigma_x)

# %%
X_s = np.dot(S.T, X.T).T
sns.jointplot(X_s[:,0], X_s[:,1], xlim=(-20,20), ylim=(-20,20))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # 白色化

# %%
X_s = np.dot(S.T, X.T).T
z_X_s = zscore(X_s)
sns.jointplot(z_X_s[:,0], z_X_s[:,1], xlim=(-20,20), ylim=(-20,20))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
