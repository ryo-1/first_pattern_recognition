# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
def make_X(mu, sigme, size):
    X = np.random.multivariate_normal(mu, sigma, size)
    return X

# %%
def gaussian(X, mu, sigma):
    g = 1/np.sqrt((2*np.pi)**len(X.T))*np.sqrt(np.abs(sigma))
    print((X-mu).shape)
    gg = np.exp(-0.5 * (X-mu).dot(1/sigma).dot((X-mu).T))
    Z = g*gg
    return Z

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 1000

X = make_X(mu,sigma, size)

#plt.scatter(X[:,0], X[:,1])
#plt.show()
sns.jointplot(X[:,0], X[:,1])
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)

#print(gaussian(X, mu_x, sigma_x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [0.20361178 0.07612474]
# sigma= [[32.39424974 20.35336162]
#  [20.35336162 48.76466501]]

# %%
mu = np.array([100, -20])
sigma = np.array([[30, 20], [20, 50]])
size = 10000

X = make_X(mu,sigma, size)

#plt.scatter(X[:,0], X[:,1])
#plt.show()
sns.jointplot(X[:,0], X[:,1])
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)

#print(gaussian(X, mu_x, sigma_x))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [100.08425734 -19.99939022]
# sigma= [[29.91922434 20.41689054]
#  [20.41689054 50.30524716]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 1000000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [-0.00307243  0.00518656]
# sigma= [[30.0287848  20.00178768]
#  [20.00178768 50.00552382]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])

X_len = np.arange(10**2,10**5,10**3)

X = np.array([make_X(mu, sigma, size) for size in X_len])

print('OK')
# Out:
# OK

# %%
mu_x = np.array([np.mean(X[i],axis=0) for i in range(len(X))])
#print("mu=",mu_x)

sigma_x = np.array([np.cov(X[i].T) for i in range(len(X))])
#print("sigma=",sigma_x)

plt.plot(X_len,  np.abs(mu - mu_x).mean(axis=1), c='r')
plt.plot(X_len, np.abs((sigma - sigma_x).mean(axis=1).mean(axis=1)))
plt.show()

# %%
mu = np.array([0, 0])
sigma = np.array([[3000, 20], [20, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [ 0.66785375 -0.00789073]
# sigma= [[2963.00783119   15.50971045]
#  [  15.50971045   49.41598598]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 5000]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [ 0.01573614 -0.20712656]
# sigma= [[  29.96537402   16.90748241]
#  [  16.90748241 4915.95369311]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 30], [30, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [0.02430308 0.01586137]
# sigma= [[29.65619597 29.78436295]
#  [29.78436295 49.72324928]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 10], [10, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [0.01340655 0.11740894]
# sigma= [[30.12030802 10.45288802]
#  [10.45288802 49.94135268]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, -30], [-30, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [ 0.05950336 -0.06389782]
# sigma= [[ 30.39287195 -30.27117673]
#  [-30.27117673  50.36578763]]

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 10000

X = make_X(mu, sigma, size)

sns.jointplot(X[:,0], X[:,1])
plt.show()
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [-0.03455078  0.04793029]
# sigma= [[29.49647502 19.51936401]
#  [19.51936401 49.6848991 ]]

# %% [markdown]
# # 標準化

# %%
def zscore(x):
    xmean = x.mean(axis=0)
    xstd = np.std(x,axis=0)
    return (x - xmean) / xstd

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 20], [20, 50]])
size = 10000

X = zscore(make_X(mu,sigma, size))

sns.jointplot(X[:,0], X[:,1], xlim=(-20,20), ylim=(-20,20))
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [-7.25641769e-15 -2.85416135e-15]
# sigma= [[1.001001  0.4759826]
#  [0.4759826 1.001001 ]]

# %% [markdown]
# # 無相関化

# %%
mu = np.array([0, 0])
sigma = np.array([[30, 5], [5, 5]])
size = 10000

X = make_X(mu,sigma, size)

sns.jointplot(X[:,0], X[:,1], xlim=(-20,20), ylim=(-20,20))
    
mu_x = X.mean(axis=0)
print("mu=",mu_x)

sigma_x = np.cov(X.T)
print("sigma=",sigma_x)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# mu= [ 0.07029041 -0.00900264]
# sigma= [[29.87515407  4.92003428]
#  [ 4.92003428  4.94413913]]

# %%
ramda, S = np.linalg.eig(sigma_x)

# %%
X_s = np.dot(S.T, X.T).T
sns.jointplot(X_s[:,0], X_s[:,1], xlim=(-20,20), ylim=(-20,20))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
X_s = np.dot(S.T, X.T).T
z_X_s = zscore(X_s)
sns.jointplot(z_X_s[:,0], z_X_s[:,1], xlim=(-20,20), ylim=(-20,20))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
